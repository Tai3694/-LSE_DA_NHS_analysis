# %%
# Import Pandas and NumPy.
import pandas as pd
import numpy as np

# %%
# Read CSV file from the current working directory.
ad = pd.read_csv('actual_duration.csv')

ar = pd.read_csv('appointments_regional.csv')

nc = pd.read_excel('national_categories.xlsx')

# %%
# Change the date format of ad['appointment_date'].
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'])

# View the DataFrame.
ad.info()

#View the DataFrame
ad.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  datetime64[ns]
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 8.4+ MB
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# ...

# %%
# Change the date format of ad['appointment_date'].
ar['appointment_month'] = pd.to_datetime(ar['appointment_month'])

# View the DataFrame.
ar.info()

#View the DataFrame
ar.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  datetime64[ns]
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 31.9+ MB
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034        2020-01-01           Attended       GP     Face-to-Face
# ...

# %% [markdown]
# ## Assignment 6

# %% [markdown]
# Part 2 - Prepare workstation

# %%
#Need to import more packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#See first five rows
ar.head(5)
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 1    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 2    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 3    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 4    E54000034        2020-01-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
#Minimum and maximum dates
print (ar.appointment_month.min())
print (ar.appointment_month.max())
# Out:
# 2020-01-01 00:00:00
# 2022-06-01 00:00:00

# %%
#Filter Dataframe 
ar2 = ar[(ar['appointment_month'] > '2021-07-01')]

#View Dataframe
print(ar2)
ar2.head()
ar2.columns
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 3652      E54000034        2021-08-01           Attended       GP
# 3653      E54000034        2021-08-01           Attended       GP
# 3654      E54000034        2021-08-01           Attended       GP
# 3655      E54000034        2021-08-01           Attended       GP
# 3656      E54000034        2021-08-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050        2022-06-01            Unknown  Unknown
# 596817    E54000050        2022-06-01            Unknown  Unknown
# 596818    E54000050        2022-06-01            Unknown  Unknown
# 596819    E54000050        2022-06-01            Unknown  Unknown
# 596820    E54000050        2022-06-01            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 3652       Face-to-Face                             1 Day
# ...

# %% [markdown]
# ## Question 1

# %% [markdown]
# 1

# %%
#Using groupby()
ar_agg = ar.groupby(['appointment_month',
                           'hcp_type',
                          'appointment_status',
                          'appointment_mode',
                          'time_between_book_and_appointment']).sum([]).reset_index()

#View DataFrame
ar_agg
# Out:
#       appointment_month hcp_type appointment_status appointment_mode  \
# 0            2020-01-01       GP           Attended     Face-to-Face
# 1            2020-01-01       GP           Attended     Face-to-Face
# 2            2020-01-01       GP           Attended     Face-to-Face
# 3            2020-01-01       GP           Attended     Face-to-Face
# 4            2020-01-01       GP           Attended     Face-to-Face
# ...                 ...      ...                ...              ...
# 10134        2022-06-01  Unknown            Unknown          Unknown
# 10135        2022-06-01  Unknown            Unknown          Unknown
# 10136        2022-06-01  Unknown            Unknown          Unknown
# 10137        2022-06-01  Unknown            Unknown          Unknown
# 10138        2022-06-01  Unknown            Unknown     Video/Online
#
#       time_between_book_and_appointment  \
# 0                                 1 Day
# 1                        15  to 21 Days
# ...

# %% [markdown]
# 2

# %%
ar_df = ar2.groupby(['appointment_month']).sum(['count_of_appointments'])

#View dataframe
ar_df

#New column 
ar_df['utilisation'] = ar_df['count_of_appointments']/30

#View dataframe
print(ar_df)
# Out:
#                    count_of_appointments   utilisation
# appointment_month
# 2021-08-01                      23852171  7.950724e+05
# 2021-09-01                      28522501  9.507500e+05
# 2021-10-01                      30303834  1.010128e+06
# 2021-11-01                      30405070  1.013502e+06
# 2021-12-01                      25140776  8.380259e+05
# 2022-01-01                      25635474  8.545158e+05
# 2022-02-01                      25355260  8.451753e+05
# 2022-03-01                      29595038  9.865013e+05
# 2022-04-01                      23913060  7.971020e+05
# 2022-05-01                      27495508  9.165169e+05
# 2022-06-01                      25828078  8.609359e+05

# %%
#Round utiltisation to one decimal place 
ar_df['utilisation2'] = ar_df['utilisation'].round(decimals = 1)

print(ar_df)
# Out:
#                    count_of_appointments   utilisation  utilisation2
# appointment_month
# 2021-08-01                      23852171  7.950724e+05      795072.4
# 2021-09-01                      28522501  9.507500e+05      950750.0
# 2021-10-01                      30303834  1.010128e+06     1010127.8
# 2021-11-01                      30405070  1.013502e+06     1013502.3
# 2021-12-01                      25140776  8.380259e+05      838025.9
# 2022-01-01                      25635474  8.545158e+05      854515.8
# 2022-02-01                      25355260  8.451753e+05      845175.3
# 2022-03-01                      29595038  9.865013e+05      986501.3
# 2022-04-01                      23913060  7.971020e+05      797102.0
# 2022-05-01                      27495508  9.165169e+05      916516.9
# 2022-06-01                      25828078  8.609359e+05      860935.9

# %% [markdown]
# 3

# %%
#Need to import more packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set the colour/plot style.
plt.figure(figsize=(15, 12))
sns.set_style('white')

sns.lineplot(x='appointment_month', y='count_of_appointments',
             data=ar_df, ci=None)

plt.savefig('Number of monthly visits.png')

# %%
# Set the colour/plot style.
plt.figure(figsize=(15, 12))
sns.set_style('white')

sns.lineplot(x='appointment_month', y='utilisation2',
             data=ar_df, ci=None)

plt.savefig('Average utilisation of services.png')

# %% [markdown]
# ## Question 2

# %%
#Set the colour/plot style
plt.figure(figsize=(15, 12))
sns.set_style('white')

#Create plot
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='hcp_type',
             data=ar_agg, ci=None)
#Save plot
plt.savefig('Healthcare professional over time.png')

# %% [markdown]
# ## Question 3

# %%
#Set the colour/plot style
plt.figure(figsize=(15, 12))
sns.set_style('white')

#Create plot
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_status',
             data=ar_agg, ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %% [markdown]
# ## Question 4

# %%
#Set the colour/plot style
plt.figure(figsize=(15, 12))
sns.set_style('white')

#Create plot
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_mode',
             data=ar_agg, ci=None)
#Save plot
plt.savefig('Mode of appointment over time.png')

# %% [markdown]
# ## Question 5

# %%
#Set the colour/plot style
plt.figure(figsize=(15, 12))
sns.set_style('white')

#Create plot
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='time_between_book_and_appointment',
             data=ar_agg, ci=None)

#Save plot
plt.savefig('Time between booking and attending appointment.png')

# %% [markdown]
# ## Question 6

# %%
#View DataFrame
print(nc)
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
#Sum of the records per month
nc_ss = nc.groupby(['service_setting','appointment_month']).sum(['count_of_appointments'])

#Sum of the records per month for each service setting
print(nc_ss)
# Out:
#                                              count_of_appointments
# service_setting           appointment_month
# Extended Access Provision 2021-08                           160927
#                           2021-09                           187906
#                           2021-10                           209539
#                           2021-11                           207577
#                           2021-12                           173504
#                           2022-01                           186375
#                           2022-02                           196627
#                           2022-03                           231905
#                           2022-04                           192284
#                           2022-05                           220511
#                           2022-06                           209652
# General Practice          2021-08                         21575852
# ...

# %%
#Set the colour/plot style
plt.figure(figsize=(15, 12))
sns.set_style('white')

#Create plot - all service settings
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='service_setting',
             data=nc_ss, ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>

# %%
#Remove GP from nc
nc_ss2 = nc[nc['service_setting'] != 'General Practice']
print(nc_ss2)
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 6            2021-08-02    E54000050
# 7            2021-08-02    E54000050
# 8            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 6       NHS North East and North Cumbria ICB - 00L                   Unmapped
# 7       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 8       NHS North East and North Cumbria ICB - 00L                      Other
# ...

# %%
#Set the colour/plot style
plt.figure(figsize=(15, 12))
sns.set_style('white')

#Create plot - all service settings except GP
sns.lineplot(x='appointment_month', y='count_of_appointments', hue='service_setting',
             data=nc_ss2, ci=None)
# Out:
# <AxesSubplot:xlabel='appointment_month', ylabel='count_of_appointments'>
